# %%
from keras.applications.inception_v3 import InceptionV3
from keras.preprocessing import image
from keras.applications.inception_v3 import preprocess_input, decode_predictions
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
model = InceptionV3(weights='imagenet')
# Out:
# WARNING:tensorflow:From /home/asus-pc/anaconda3/envs/tf-gpu/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /home/asus-pc/anaconda3/envs/tf-gpu/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/asus-pc/anaconda3/envs/tf-gpu/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /home/asus-pc/anaconda3/envs/tf-gpu/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# ...

# %%
img_path = '/home/asus-pc/workspace/jyu/deeplearning/notebooks/deep_neural_network/input/keras_model_classify/goat.jpg'

img = image.load_img(img_path, target_size=(299, 299))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
img
# Out:
# <PIL.Image.Image image mode=RGB size=299x299 at 0x7FE3D8487BD0>

# %%
preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Predicted: [(u'n02504013', u'Indian_elephant', 0.82658225), (u'n01871265', u'tusker', 0.1122357), (u'n02504458', u'African_elephant', 0.061040461)]
# Out:
# Predicted: [('n02423022', 'gazelle', 0.20449245), ('n02422699', 'impala', 0.10729586), ('n02403003', 'ox', 0.052027147)]

# %%
# img_path = '/home/asus-pc/workspace/jyu/deeplearning/notebooks/deep_neural_network/input/keras_model_classify/cat.jpg'

# img_path = '/home/asus-pc/workspace/jyu/deeplearning/notebooks/deep_neural_network/input/keras_model_classify/cat2.png'

# img_path = '/home/asus-pc/workspace/jyu/deeplearning/notebooks/deep_neural_network/input/keras_model_classify/elephant1.jpg'

# img_path = '/home/asus-pc/workspace/jyu/deeplearning/notebooks/deep_neural_network/input/keras_model_classify/elephant2.jpg'

# img_path = '/home/asus-pc/workspace/jyu/deeplearning/notebooks/deep_neural_network/input/keras_model_classify/kite.jpg'


# img_path = '/home/asus-pc/workspace/jyu/deeplearning/notebooks/deep_neural_network/input/keras_model_classify/ski.png'

# img_path = '/home/asus-pc/workspace/jyu/deeplearning/notebooks/deep_neural_network/input/keras_model_classify/snowmobile.jpg'

# img_path = '/home/asus-pc/workspace/jyu/deeplearning/notebooks/deep_neural_network/input/keras_model_classify/soccer.jpg'

# img_path = '/home/asus-pc/workspace/jyu/deeplearning/notebooks/deep_neural_network/input/keras_model_classify/turtle.png'

# img_path = '/home/asus-pc/workspace/jyu/deeplearning/notebooks/deep_neural_network/input/keras_model_classify/goat.jpg'
